# %% [markdown]
# ## Check version

# %%
import pandas as pd 
print("Pandas version",pd.__version__)
# Out:
# Pandas version 2.2.1

# %% [markdown]
# ## Install matplotlib

# %%
! pip install matplotlib

# %% [markdown]
# ## get data

# %%
data = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/air_quality_no2.csv')
data
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %% [markdown]
# ## Use Matplotlib

# %%
import matplotlib.pyplot as mat

# %% [markdown]
# ## Mayplotlib: Line graph

# %%
data.plot()
mat.show()

# %% [markdown]
# ## Matplotlib: Select

# %%
data['station_paris'].plot()
mat.show()

# %% [markdown]
# ## Matplotli: Scatter

# %%
data.plot.scatter(x="station_london", y="station_paris", alpha=0.5)
mat.show()

# %% [markdown]
# ## Matplotlib: Plot + Box

# %%
data.plot.box()
mat.show()

# %% [markdown]
# ## Matplotlib: Area

# %%
axs = data.plot.area(figsize=(12, 4), subplots=True)
mat.show()

# %% [markdown]
# ## REMEMBER
# The .plot.* methods are applicable on both Series and DataFrames.
#
# By default, each of the columns is plotted as a different element (line, boxplot,…).
#
# Any plot created by pandas is a Matplotlib object.
